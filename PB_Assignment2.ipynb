# %%
import numpy as np

# %%
import matplotlib.pyplot as py

# %%
import pandas as pd

# %%
dataset=pd.read_csv("G:\College\Data Mining\Assignments\Mall_Customers.csv")

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
x=dataset.iloc[:,:-1].values

# %%
y=dataset.iloc[:,4].values

# %%
x
# Out:
# array([[1, 'Male', 19, 15],
#        [2, 'Male', 21, 15],
#        [3, 'Female', 20, 16],
#        [4, 'Female', 23, 16],
#        [5, 'Female', 31, 17],
#        [6, 'Female', 22, 17],
#        [7, 'Female', 35, 18],
#        [8, 'Female', 23, 18],
#        [9, 'Male', 64, 19],
#        [10, 'Female', 30, 19],
#        [11, 'Male', 67, 19],
#        [12, 'Female', 35, 19],
#        [13, 'Female', 58, 20],
#        [14, 'Female', 24, 20],
#        [15, 'Male', 37, 20],
#        [16, 'Male', 22, 20],
#        [17, 'Female', 35, 21],
#        [18, 'Male', 20, 21],
#        [19, 'Male', 52, 23],
#        [20, 'Female', 35, 23],
#        [21, 'Male', 35, 24],
#        [22, 'Male', 25, 24],
#        [23, 'Female', 46, 25],
#        [24, 'Male', 31, 25],
#        [25, 'Female', 54, 28],
#        [26, 'Male', 29, 28],
#        [27, 'Female', 45, 28],
#        [28, 'Male', 35, 28],
#        [29, 'Female', 40, 29],
#        [30, 'Female', 23, 29],
#        [31, 'Male', 60, 30],
# ...

# %%
y
# Out:
# array([39, 81,  6, 77, 40, 76,  6, 94,  3, 72, 14, 99, 15, 77, 13, 79, 35,
#        66, 29, 98, 35, 73,  5, 73, 14, 82, 32, 61, 31, 87,  4, 73,  4, 92,
#        14, 81, 17, 73, 26, 75, 35, 92, 36, 61, 28, 65, 55, 47, 42, 42, 52,
#        60, 54, 60, 45, 41, 50, 46, 51, 46, 56, 55, 52, 59, 51, 59, 50, 48,
#        59, 47, 55, 42, 49, 56, 47, 54, 53, 48, 52, 42, 51, 55, 41, 44, 57,
#        46, 58, 55, 60, 46, 55, 41, 49, 40, 42, 52, 47, 50, 42, 49, 41, 48,
#        59, 55, 56, 42, 50, 46, 43, 48, 52, 54, 42, 46, 48, 50, 43, 59, 43,
#        57, 56, 40, 58, 91, 29, 77, 35, 95, 11, 75,  9, 75, 34, 71,  5, 88,
#         7, 73, 10, 72,  5, 93, 40, 87, 12, 97, 36, 74, 22, 90, 17, 88, 20,
#        76, 16, 89,  1, 78,  1, 73, 35, 83,  5, 93, 26, 75, 20, 95, 27, 63,
#        13, 75, 10, 92, 13, 86, 15, 69, 14, 90, 32, 86, 15, 88, 39, 97, 24,
#        68, 17, 85, 23, 69,  8, 91, 16, 79, 28, 74, 18, 83], dtype=int64)

# %%
x=dataset.iloc[:,:-3].values

# %%
x
# Out:
# array([[1, 'Male'],
#        [2, 'Male'],
#        [3, 'Female'],
#        [4, 'Female'],
#        [5, 'Female'],
#        [6, 'Female'],
#        [7, 'Female'],
#        [8, 'Female'],
#        [9, 'Male'],
#        [10, 'Female'],
#        [11, 'Male'],
#        [12, 'Female'],
#        [13, 'Female'],
#        [14, 'Female'],
#        [15, 'Male'],
#        [16, 'Male'],
#        [17, 'Female'],
#        [18, 'Male'],
#        [19, 'Male'],
#        [20, 'Female'],
#        [21, 'Male'],
#        [22, 'Male'],
#        [23, 'Female'],
#        [24, 'Male'],
#        [25, 'Female'],
#        [26, 'Male'],
#        [27, 'Female'],
#        [28, 'Male'],
#        [29, 'Female'],
#        [30, 'Female'],
#        [31, 'Male'],
#        [32, 'Female'],
#        [33, 'Male'],
#        [34, 'Male'],
#        [35, 'Female'],
#        [36, 'Female'],
#        [37, 'Female'],
#        [38, 'Female'],
#        [39, 'Female'],
#        [40, 'Female'],
#        [41, 'Female'],
# ...

# %%
from sklearn.preprocessing import Imputer

# %%
imputer=Imputer(missing_values='NaN', strategy='mean',axis=0)
# Out:
# C:\Users\Mandovi\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
imputer=Imputer(missing_values='NaN', strategy='mean',axis=0)
imputer=imputer.fit(x[:,2:3])
x[:,2:3]=imputer.transform(x[:,2:3])
# Out:
# C:\Users\Mandovi\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-2670c346f9b4> in <module>
#       1 imputer=Imputer(missing_values='NaN', strategy='mean',axis=0)
# ----> 2 imputer=imputer.fit(x[:,2:3])
#       3 x[:,2:3]=imputer.transform(x[:,2:3])
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\imputation.py in fit(self, X, y)
#     156         if self.axis == 0:
#     157             X = check_array(X, accept_sparse='csc', dtype=np.float64,
# --> 158                             force_all_finite=False)
#     159
#     160             if sparse.issparse(X):
#
# ...

# %%
x
# Out:
# array([[1, 'Male'],
#        [2, 'Male'],
#        [3, 'Female'],
#        [4, 'Female'],
#        [5, 'Female'],
#        [6, 'Female'],
#        [7, 'Female'],
#        [8, 'Female'],
#        [9, 'Male'],
#        [10, 'Female'],
#        [11, 'Male'],
#        [12, 'Female'],
#        [13, 'Female'],
#        [14, 'Female'],
#        [15, 'Male'],
#        [16, 'Male'],
#        [17, 'Female'],
#        [18, 'Male'],
#        [19, 'Male'],
#        [20, 'Female'],
#        [21, 'Male'],
#        [22, 'Male'],
#        [23, 'Female'],
#        [24, 'Male'],
#        [25, 'Female'],
#        [26, 'Male'],
#        [27, 'Female'],
#        [28, 'Male'],
#        [29, 'Female'],
#        [30, 'Female'],
#        [31, 'Male'],
#        [32, 'Female'],
#        [33, 'Male'],
#        [34, 'Male'],
#        [35, 'Female'],
#        [36, 'Female'],
#        [37, 'Female'],
#        [38, 'Female'],
#        [39, 'Female'],
#        [40, 'Female'],
#        [41, 'Female'],
# ...

# %%
x=dataset.iloc[:,:-1].values

# %%
x
# Out:
# array([[1, 'Male', 19, 15],
#        [2, 'Male', 21, 15],
#        [3, 'Female', 20, 16],
#        [4, 'Female', 23, 16],
#        [5, 'Female', 31, 17],
#        [6, 'Female', 22, 17],
#        [7, 'Female', 35, 18],
#        [8, 'Female', 23, 18],
#        [9, 'Male', 64, 19],
#        [10, 'Female', 30, 19],
#        [11, 'Male', 67, 19],
#        [12, 'Female', 35, 19],
#        [13, 'Female', 58, 20],
#        [14, 'Female', 24, 20],
#        [15, 'Male', 37, 20],
#        [16, 'Male', 22, 20],
#        [17, 'Female', 35, 21],
#        [18, 'Male', 20, 21],
#        [19, 'Male', 52, 23],
#        [20, 'Female', 35, 23],
#        [21, 'Male', 35, 24],
#        [22, 'Male', 25, 24],
#        [23, 'Female', 46, 25],
#        [24, 'Male', 31, 25],
#        [25, 'Female', 54, 28],
#        [26, 'Male', 29, 28],
#        [27, 'Female', 45, 28],
#        [28, 'Male', 35, 28],
#        [29, 'Female', 40, 29],
#        [30, 'Female', 23, 29],
#        [31, 'Male', 60, 30],
# ...

# %%
from sklearn.preprocessing import Imputer
imputer=Imputer(missing_values='NaN', strategy='mean',axis=0)
imputer=imputer.fit(x[:,2:3])
x[:,2:3]=imputer.transform(x[:,2:3])
# Out:
# C:\Users\Mandovi\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
from sklearn.preprocessing import impute.SimpleImputer
imputer=Imputer(missing_values='NaN', strategy='mean',axis=0)
imputer=imputer.fit(x[:,2:3])
x[:,2:3]=imputer.transform(x[:,2:3])
# Out:
#   File "<ipython-input-20-c6a3b493ba7e>", line 1
#     from sklearn.preprocessing import impute.SimpleImputer
#                                             ^
# SyntaxError: invalid syntax

# %%
from sklearn.preprocessing import impute.SimpleImputer
imputer=SimpleImputer(missing_values='NaN', strategy='mean',axis=0)
imputer=SimpleImputer.fit(x[:,2:3])
x[:,2:3]=SimpleImputer.transform(x[:,2:3])
# Out:
#   File "<ipython-input-21-3da60ac41c57>", line 1
#     from sklearn.preprocessing import impute.SimpleImputer
#                                             ^
# SyntaxError: invalid syntax

# %%
x
# Out:
# array([[1, 'Male', 19.0, 15],
#        [2, 'Male', 21.0, 15],
#        [3, 'Female', 20.0, 16],
#        [4, 'Female', 23.0, 16],
#        [5, 'Female', 31.0, 17],
#        [6, 'Female', 22.0, 17],
#        [7, 'Female', 35.0, 18],
#        [8, 'Female', 23.0, 18],
#        [9, 'Male', 64.0, 19],
#        [10, 'Female', 30.0, 19],
#        [11, 'Male', 67.0, 19],
#        [12, 'Female', 35.0, 19],
#        [13, 'Female', 58.0, 20],
#        [14, 'Female', 24.0, 20],
#        [15, 'Male', 37.0, 20],
#        [16, 'Male', 22.0, 20],
#        [17, 'Female', 35.0, 21],
#        [18, 'Male', 20.0, 21],
#        [19, 'Male', 52.0, 23],
#        [20, 'Female', 35.0, 23],
#        [21, 'Male', 35.0, 24],
#        [22, 'Male', 25.0, 24],
#        [23, 'Female', 46.0, 25],
#        [24, 'Male', 31.0, 25],
#        [25, 'Female', 54.0, 28],
#        [26, 'Male', 29.0, 28],
#        [27, 'Female', 45.0, 28],
#        [28, 'Male', 35.0, 28],
#        [29, 'Female', 40.0, 29],
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_x=LabelEncoder()
x[:,1]=labelencoder_x.fit_transform(x[:,1])

# %%
x
# Out:
# array([[1, 1, 19.0, 15],
#        [2, 1, 21.0, 15],
#        [3, 0, 20.0, 16],
#        [4, 0, 23.0, 16],
#        [5, 0, 31.0, 17],
#        [6, 0, 22.0, 17],
#        [7, 0, 35.0, 18],
#        [8, 0, 23.0, 18],
#        [9, 1, 64.0, 19],
#        [10, 0, 30.0, 19],
#        [11, 1, 67.0, 19],
#        [12, 0, 35.0, 19],
#        [13, 0, 58.0, 20],
#        [14, 0, 24.0, 20],
#        [15, 1, 37.0, 20],
#        [16, 1, 22.0, 20],
#        [17, 0, 35.0, 21],
#        [18, 1, 20.0, 21],
#        [19, 1, 52.0, 23],
#        [20, 0, 35.0, 23],
#        [21, 1, 35.0, 24],
#        [22, 1, 25.0, 24],
#        [23, 0, 46.0, 25],
#        [24, 1, 31.0, 25],
#        [25, 0, 54.0, 28],
#        [26, 1, 29.0, 28],
#        [27, 0, 45.0, 28],
#        [28, 1, 35.0, 28],
#        [29, 0, 40.0, 29],
#        [30, 0, 23.0, 29],
#        [31, 1, 60.0, 30],
#        [32, 0, 21.0, 30],
#        [33, 1, 53.0, 33],
#        [34, 1, 18.0, 33],
#        [35, 0, 49.0, 33],
#        [36, 0, 21.0, 33],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-899c6c9eba3c> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
#
# ValueError: too many values to unpack (expected 3)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
len(x_train)
# Out:
# 160

# %%
len(x_test)
# Out:
# 40

# %%
len(y_train)
# Out:
# 160

# %%
len(y_test)
# Out:
# 40

# %%
from sklearn.preprocessing import StandardScaler
sc_x= StandardScaler()
x_train=sc_x.fit_transform(x_train)
x_test=sc.x.fit_transform(x_test)
# Out:
# C:\Users\Mandovi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Mandovi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-6965fbc4cd95> in <module>
#       2 sc_x= StandardScaler()
#       3 x_train=sc_x.fit_transform(x_train)
# ----> 4 x_test=sc.x.fit_transform(x_test)
#
# NameError: name 'sc' is not defined

# %%
from sklearn.preprocessing import StandardScaler
sc_x= StandardScaler()
x_train=sc_x.fit_transform(x_train)
x_test=sc_x.fit_transform(x_test)
# Out:
# C:\Users\Mandovi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Mandovi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
x_train=sc_x.fit_transform(x_train)
x_test=sc_x.fit_transform(x_test)

# %%
len(x_train)
# Out:
# 160

# %%
x_train
# Out:
# array([[ 6.14101752e-01,  1.16316000e+00, -1.31358807e+00,
#          4.71130603e-01],
#        [-5.79436487e-01, -8.59726954e-01,  3.07472996e-01,
#         -4.80648393e-01],
#        [-1.28151780e+00, -8.59726954e-01,  4.48434827e-01,
#         -1.24207159e+00],
#        [ 2.45509061e-01,  1.16316000e+00, -1.38406899e+00,
#          1.28490165e-01],
#        [ 1.21087087e+00, -8.59726954e-01, -1.85893416e-01,
#          1.00412684e+00],
#        [-6.32092586e-01, -8.59726954e-01,  1.08276307e+00,
#         -5.18719553e-01],
#        [-1.59745440e+00,  1.16316000e+00,  1.78757223e+00,
#         -1.58471203e+00],
#        [-4.21468191e-01,  1.16316000e+00, -8.90702575e-01,
#         -2.52221434e-01],
#        [ 3.33269225e-01, -8.59726954e-01,  8.71320323e-01,
#          2.42703644e-01],
#        [ 7.72070049e-01, -8.59726954e-01, -4.67817079e-01,
#          5.85344083e-01],
#        [-4.91676323e-01, -8.59726954e-01,  5.89396659e-01,
#         -4.42577234e-01],
# ...
